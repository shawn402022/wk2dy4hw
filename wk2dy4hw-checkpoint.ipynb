# %%
class S_CartComputer():
    """
        The class S_CartComputer will have, capacity, cost, 
        coupons, and items to place inside.
        
        Attributes for the class:
        -capacity : expected integer
        -cost: expected integer
        -coupon: expected integer
        -noStock: expected string
        -inStock: expected dictionary
        -savings: expected percentage
        -items: expected list unless dictionaries are allowed.
        
    """
    
    def __init__(self,capacity,cost,coupons,noStock,inStock,savings, items):
        self.capacity = capacity
        self.cost = cost
        self.coupons = coupons
        self.noStock = noStock
        self.inStock = inStock
        self.savings = savings
        self.items = items
        
    #Method shows the names of the items as well as the count
    
    def CurrentStock(self):
        cStore = {
            'milk':7.99,
            'bread':2.99,
            'water':1.99,
            'cheese':6.99,
            'cookies':2.99,
            'icecream':5.99,
            'toilet paper':11.99,
            'ceral':12.99,
            'frozen pizza':10.99,
            'chicken': 12.00,
            'beef':13.00,
            'fish':16.99,
            'juice':6.99

    
        }
        
        cStoreCoupon = []
        

        
    def countItems(self):
        print("you have {self.capacity} items, they are : (self.items)")
        for item in self.items:
            print(item)
    
    #method adds items to cart
    def addToCart(self):
        addProducts = input("what would you like to add, please choose from the list.Some Items may not be in stock ")
        print(self.cStore[key])
        
        if addProducts in self.cStore:
            self.items.append(self.cStore[k])
            self.cost.append(self.cStore[v])
        print('{addProducts} has been added to your cart')
        
        else:
            print('{addProducts} is not in stock at the moment.')
            
    #method to show cart items, and cart savings
    def savings(self):
        savings = input("would you like to use coupons Y/N? you can use 1 20% coupon per month. Save those for big purchases!, )
        if savings == "Y":
            self.coupon.pop(sum(self.cost) * 20%) - sum(self.items[val])
        print(" Today you saved $(self.coupon)")
            
        else:
            pass
                
    # method to check out and print total
    def checkout(self):
        showCart = input('would you like to see current the items in your cart? Y/N')
        if showCart == "y":
            print("{self.items}")
        
        else:
            pass
#             checkOut= input("would you like to check out?")
#                 if checkOut == "Y":
#                     print(self.items)
#                     print('your total is {self.coupon} Thanks fore sohpping with us')
# Out:
#   Input In [3]
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
#instance of the S_CartComputer class
acmeCart = S_CartComputer()

#Create Function to run the S_CartComputer(acmeCart) methods

def sCartRun():
    #instace of class
    while True:
        salutation = input("welcome to Acme, would you like to add/show/checkout/savings/quit?")
        
        if salutation.lower() =="quit":
            print("Thanks for shopping with us, hope to see you back soon!")
            break
        elif salutation.lower() == 'add':
            acmeCart.addToCart()
        
        elif salutation.lower() == 'show':
            acmeCart.countItems()
            
        elif salutation.lower() == 'savings':
            acmeCart.savings()
            
        elif salutation.lower() == "checkout":
            acmeCart.checkOut()
            
sCartRun()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 #instance of the S_CartComputer class
# ----> 2 acmeCart = S_CartComputer()
#       4 #Create Function to run the S_CartComputer(acmeCart) methods
#       6 def sCartRun():
#       7     #instace of class
#
# NameError: name 'S_CartComputer' is not defined

# %%
# type(cStore())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 type(cStore())
#
# NameError: name 'cStore' is not defined

# %%
# class S_CartComputer():
#     """
#         The class S_CartComputer will have, capacity, cost, 
#         coupons, and items to place inside.
        
#         Attributes for the class:
#         -capacity : expected integer
#         -cost: expected integer
#         -coupons: expected boolean
#         -noStock: expected string
#         -inStock: expected dictionary
#         -savings: expected integer
#         -items: expected list unless dictionaries are allowed.
        
#     """
    
#     def __init__(self,capacity,cost,coupons,noStock,inStock,savings, items):
#         self.capacity = capacity
#         self.cost = cost
#         self.coupons = coupons
#         noStock = noStock
#         inStock = inStock
#         savings = savings
#         self.items = items
        
#     #Method shows the names of the items as well as the count
    
#     def CurrentStock(self):
#         cStore = {
#             'milk':7.99,
#             'bread':2.99,
#             'water':1.99,
#             'cheese':6.99,
#             'cookies':2.99,
#             'icecream':5.99,
#             'toilet paper':11.99,
#             'ceral':12.99,
#             'frozen pizza':10.99,
#             'chicken': 12.00,
#             'beef':13.00,
#             'fish':16.99,
#             'juice':6.99
    
# }
#         coupons = {
#             'milk':.99,
#             'bread':.50,
#             'water':.25,
#             'cheese':.35,
#             'cookies':.70,
#             'icecream':.35,
#             'toilet paper':1.99,
#             'ceral':2.99,
#             'frozen pizza':1.99,
#             'chicken': 1.00,
#             'beef':3.00,
#             'fish':1.99,
#             'juice':.99
#             ''
#         }
        
#     def CountItems(self):
#         print("you have {self.capacity} items, they are : (self.items)")
#         for item in self.items:
#             print(item)
    
#     #method adds items to cart
#     def addToCart(self):
#         addProducts = input("what would you like to add, please choose from the list.Some Items may not be in stock ")
        
#         if addProducts in cStore:
#             self.items.append(self.cStore.keys())
#             self.cost.append(self.cStore.val())
#         print('{addProducts} has been added to your cart')
        
#         else:
#             print('{addProducts} is not in stock at the moment.')
            
#     #method to show cart items, and cart savings
#     def savings(self):
#         savings = input("would you like to know how much you saved today? Y/N")
#         if savings == "Y":
#             for item in self.items:
                
        
#         showCart = input('would you like to see current the items in your cart? Y/N')
#         if showCart == "y":
#             print("{self.items}")
